# %% [markdown]
#  # Importing Required Libraries

# %%
import numpy as nd
import pandas as py
import matplotlib.pyplot as plw
import seaborn as sns
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,r2_score

# %% [markdown]
#  # Loading the Dataset

# %%
df = py.read_csv("D:\\Dataset\\Mall_Customers.csv")
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
#  # DataCleaning using Pandas

# %%
df.head(19)
# Out:
#     CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0            1    Male   19                  15                      39
# 1            2    Male   21                  15                      81
# 2            3  Female   20                  16                       6
# 3            4  Female   23                  16                      77
# 4            5  Female   31                  17                      40
# 5            6  Female   22                  17                      76
# 6            7  Female   35                  18                       6
# 7            8  Female   23                  18                      94
# 8            9    Male   64                  19                       3
# 9           10  Female   30                  19                      72
# 10          11    Male   67                  19                      14
# 11          12  Female   35                  19                      99
# ...

# %%
df.tail(22)
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 178         179    Male   59                  93                      14
# 179         180    Male   35                  93                      90
# 180         181  Female   37                  97                      32
# 181         182  Female   32                  97                      86
# 182         183    Male   46                  98                      15
# 183         184  Female   29                  98                      88
# 184         185  Female   41                  99                      39
# 185         186    Male   30                  99                      97
# 186         187  Female   54                 101                      24
# 187         188    Male   28                 101                      68
# 188         189  Female   41                 103                      17
# 189         190  Female   36                 103                      85
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df[df.index==32]
# Out:
#     CustomerID Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 32          33   Male   53                  33                       4

# %%
df[df.index.isin(range(32,45))]
# Out:
#     CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 32          33    Male   53                  33                       4
# 33          34    Male   18                  33                      92
# 34          35  Female   49                  33                      14
# 35          36  Female   21                  33                      81
# 36          37  Female   42                  34                      17
# 37          38  Female   30                  34                      73
# 38          39  Female   36                  37                      26
# 39          40  Female   20                  37                      75
# 40          41  Female   65                  38                      35
# 41          42    Male   24                  38                      92
# 42          43    Male   48                  39                      36
# 43          44  Female   31                  39                      61
# ...

# %%
df.loc[89]
# Out:
# CustomerID                    90
# Gender                    Female
# Age                           50
# Annual Income (k$)            58
# Spending Score (1-100)        46
# Name: 89, dtype: object

# %%
df.iloc[21:43]
# Out:
#     CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 21          22    Male   25                  24                      73
# 22          23  Female   46                  25                       5
# 23          24    Male   31                  25                      73
# 24          25  Female   54                  28                      14
# 25          26    Male   29                  28                      82
# 26          27  Female   45                  28                      32
# 27          28    Male   35                  28                      61
# 28          29  Female   40                  29                      31
# 29          30  Female   23                  29                      87
# 30          31    Male   60                  30                       4
# 31          32  Female   21                  30                      73
# 32          33    Male   53                  33                       4
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df.size
# Out:
# 1000

# %%
df.shape
# Out:
# (200, 5)

# %%
df.count()
# Out:
# CustomerID                200
# Gender                    200
# Age                       200
# Annual Income (k$)        200
# Spending Score (1-100)    200
# dtype: int64

# %%
df["Annual Income (k$)"].value_counts()
# Out:
# Annual Income (k$)
# 54     12
# 78     12
# 48      6
# 71      6
# 63      6
#        ..
# 58      2
# 59      2
# 16      2
# 64      2
# 137     2
# Name: count, Length: 64, dtype: int64

# %%
df.drop(99)
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [199 rows x 5 columns]

# %%
df.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %% [markdown]
#  # Data visualization using Matplotlib & Seaborn

# %%
import pandas as py
df = py.read_csv("D:\\Dataset\\Mall_Customers.csv")
df
if df is None:
    df = py.df()
sns.pairplot(df)
# Out:
# C:\Users\SAI\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.countplot(df["Age"])
# Out:
# <Axes: ylabel='count'>

# %%
sns.histplot(df["Annual Income (k$)"])
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Count'>

# %%
sns.jointplot(X="Spending Score (1-100)",Y="Age",data=df,kind="kde",fill=True)
plw.show()
# Out:
# C:\Users\SAI\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'X', 'Y'
#   cset = contour_func(

# %%
plw.figure(1,figsize=(15,6))
n=0;
for x in ["Age","Annual Income (k$)","CustomerID"]:
    n += 1
    plw.subplot(1,3,n)
    plw.subplots_adjust(hspace=0.5,wspace=0.5)
    sns.distplot(df[x],bins = 20)
    plw.title("Displot of {}".format(x))
plw.show()
# Out:
# C:\Users\SAI\AppData\Local\Temp\ipykernel_2176\2421358192.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[x],bins = 20)
# C:\Users\SAI\AppData\Local\Temp\ipykernel_2176\2421358192.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[x],bins = 20)
# ...

# %%
plw.figure(figsize=(20,5))
sns.countplot(y="CustomerID",data=df)
plw.show()

# %%
import matplotlib.pyplot as plw
import numpy as nd
X = nd.linspace(0,250,450)
Y1 = nd.sin(X)
Y2 = nd.cos(X)
fig,(ax1,ax2) = plw.subplots(2,sharex=True)
ax1.plot(X,Y1)
ax1.set_title("Shared X_axis")
ax2.plot(X,Y2)
plw.show()

# %%
df = nd.random.rand(10,25)
plw.imshow(df, cmap='cubehelix', interpolation='nearest')
plw.colorbar()
plw.show()

# %% [markdown]
#  # Split the data into X & Y

# %%
X = nd.delete(df,0,axis=0)
Y = nd.delete(df,0,axis=0)

# %%
# Train_Test_Split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
# Standardize the Data
Scaler = StandardScaler()
X_train = Scaler.fit_transform(X_train)
X_test = Scaler.transform(X_test)

# %% [markdown]
#  # Model Selection and Training

# %%
RF_Regs = RandomForestRegressor(random_state=42)
RF_Regs.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
Lin_Regr = LinearRegression()
Lin_Regr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
DT_Regs = DecisionTreeRegressor(random_state=42)
DT_Regs.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %% [markdown]
# # Model Evaluation

# %%
def evaluate_model(model,X_test,Y_test):
    Y_pred = model.predict(X_test)
    rmse = nd.sqrt(mean_squared_error(Y_test,Y_pred))
    r2 = r2_score(Y_test,Y_pred)
    return rmse,r2
# Evaluate Models
Lin_rmse,Lin_r2 = evaluate_model(Lin_Regr,X_test,Y_test)
DT_rmse,DT_r2 = evaluate_model(DT_Regs,X_test,Y_test)
RF_rmse,RF_r2 = evaluate_model(RF_Regs,X_test,Y_test)
print(f"Linear Regression RMSE: {Lin_rmse},R2: {Lin_r2}")
print(f"Decision Tree RMSE: {DT_rmse},R2: {DT_r2}")
print(f"Random Forest RMSE: {RF_rmse},R2: {RF_r2}")
# Out:
# Linear Regression RMSE: 0.2914554533343,R2: -7.123013039306003
# Decision Tree RMSE: 0.3858165580364551,R2: -17.945951024854217
# Random Forest RMSE: 0.2845598921114132,R2: -5.457991761672071

# %% [markdown]
# # Hyper Parameter Tuning

# %%
param_grid = {
    'n_estimators' : [100,200,300],'max_depth' : [None,10,20,30],'min_samples_split' : [2,5,10]
}
grid_search = GridSearchCV(estimator=RF_Regs,param_grid=param_grid,cv=3,n_jobs=-1,verbose=2)
grid_search.fit(X_train,Y_train)
best_rf = grid_search.best_estimator_
# Evaluate the Model
best_rf_rmse,best_rf_r2 = evaluate_model(best_rf,X_test,Y_test)
print(f"Best Random Forest RMSE: {best_rf_rmse},R2: {best_rf_r2}")
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# Best Random Forest RMSE: 0.2726797717312703,R2: -5.2431958116759105
